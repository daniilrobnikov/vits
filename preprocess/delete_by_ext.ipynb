# %%
from pathlib import Path

# Usage example
folder_path = '/gpfs/mariana/home/darobn/datasets/madasr23dataset/bn.cleaned'
extension = '.spec.pt'
log_frequency = 2000  # Log info every 1000 removed files

# %%
def remove_files_with_extension(folder_path, extension):
    p = Path(folder_path)
    files = list(p.rglob(f'*{extension}'))  # Use rglob method to search for files recursively

    counter = 0  # Counter for removed files

    for file in files:
        file.unlink()  # Use Path.unlink() for more efficient file removal
        counter += 1

        if counter % log_frequency == 0:
            print(f"Removed {counter} files")

    print(f"Total removed files: {counter}")

remove_files_with_extension(folder_path, extension)
# Out:
# Removed 1000 files
# Removed 2000 files
# Removed 3000 files
# Removed 4000 files
# Removed 5000 files
# Removed 6000 files
# Removed 7000 files
# Removed 8000 files
# Removed 9000 files
# Removed 10000 files
# Removed 11000 files
# Removed 12000 files
# Removed 13000 files
# Removed 14000 files
# Removed 15000 files
# Removed 16000 files
# Removed 17000 files
# Removed 18000 files
# Removed 19000 files
# Removed 20000 files
# Removed 21000 files
# Removed 22000 files
# Removed 23000 files
# Removed 24000 files
# Removed 25000 files
# Removed 26000 files
# Removed 27000 files
# Removed 28000 files
# Removed 29000 files
# Removed 30000 files
# Removed 31000 files
# Removed 32000 files
# Removed 33000 files
# Removed 34000 files
# Removed 35000 files
# Removed 36000 files
# Removed 37000 files
# Removed 38000 files
# Removed 39000 files
# Removed 40000 files
# Removed 41000 files
# Removed 42000 files
# Removed 43000 files
# Removed 44000 files
# Removed 45000 files
# Removed 46000 files
# Removed 47000 files
# Removed 48000 files
# Removed 49000 files
# Removed 50000 files
# Removed 51000 files
# Removed 52000 files
# Removed 53000 files
# Removed 54000 files
# Removed 55000 files
# Removed 56000 files
# Removed 57000 files
# Removed 58000 files
# Removed 59000 files
# Removed 60000 files
# Removed 61000 files
# Removed 62000 files
# Removed 63000 files
# Removed 64000 files
# Removed 65000 files
# Removed 66000 files
# Removed 67000 files
# Removed 68000 files
# Removed 69000 files
# Removed 70000 files
# Removed 71000 files
# Removed 72000 files
# Removed 73000 files
# Removed 74000 files
# Removed 75000 files
# Removed 76000 files
# Removed 77000 files
# Removed 78000 files
# Removed 79000 files
# Removed 80000 files
# Removed 81000 files
# Removed 82000 files
# Removed 83000 files
# Removed 84000 files
# Removed 85000 files
# Removed 86000 files
# Removed 87000 files
# Removed 88000 files
# Removed 89000 files
# Removed 90000 files
# Removed 91000 files
# Removed 92000 files
# Removed 93000 files
# Removed 94000 files
# Removed 95000 files
# Removed 96000 files
# Removed 97000 files
# Removed 98000 files
# Removed 99000 files
# Removed 100000 files
# Removed 101000 files
# Removed 102000 files
# Removed 103000 files
# Removed 104000 files
# Removed 105000 files
# Removed 106000 files
# Removed 107000 files
# Removed 108000 files
# Removed 109000 files
# Removed 110000 files
# Removed 111000 files
# Removed 112000 files
# Removed 113000 files
# Removed 114000 files
# Removed 115000 files
# Removed 116000 files
# Removed 117000 files
# Removed 118000 files
# Removed 119000 files
# Removed 120000 files
# Removed 121000 files
# Removed 122000 files
# Removed 123000 files
# Removed 124000 files
# Removed 125000 files
# Removed 126000 files
# Removed 127000 files
# Removed 128000 files
# Removed 129000 files
# Removed 130000 files
# Removed 131000 files
# Removed 132000 files
# Removed 133000 files
# Removed 134000 files
# Removed 135000 files
# Removed 136000 files
# Removed 137000 files
# Removed 138000 files
# Removed 139000 files
# Removed 140000 files
# Removed 141000 files
# Removed 142000 files
# Removed 143000 files
# Removed 144000 files
# Removed 145000 files
# Removed 146000 files
# Removed 147000 files
# Removed 148000 files
# Removed 149000 files
# Removed 150000 files
# Removed 151000 files
# Removed 152000 files
# Removed 153000 files
# Removed 154000 files
# Removed 155000 files
# Removed 156000 files
# Removed 157000 files
# Removed 158000 files
# Removed 159000 files
# Removed 160000 files
# Removed 161000 files
# Removed 162000 files
# Removed 163000 files
# Removed 164000 files
# Removed 165000 files
# Removed 166000 files
# Removed 167000 files
# Removed 168000 files
# Removed 169000 files
# Removed 170000 files
# Removed 171000 files
# Removed 172000 files
# Removed 173000 files
# Removed 174000 files
# Removed 175000 files
# Removed 176000 files
# Removed 177000 files
# Removed 178000 files
# Removed 179000 files
# Removed 180000 files
# Removed 181000 files
# Removed 182000 files
# Removed 183000 files
# Removed 184000 files
# Removed 185000 files
# Removed 186000 files
# Removed 187000 files
# Removed 188000 files
# Removed 189000 files
# Removed 190000 files
# Removed 191000 files
# Removed 192000 files
# Removed 193000 files
# Removed 194000 files
# Removed 195000 files
# Removed 196000 files
# Removed 197000 files
# Removed 198000 files
# Removed 199000 files
# Removed 200000 files
# Removed 201000 files
# Total removed files: 201469
